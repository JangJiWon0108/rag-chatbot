# %% [markdown]
# # 결론 : LangChain 을 사용하는 것이 매우 편리함

# %%
# 다큐먼트 로더를 사용하지 않고 파이썬의 docx 사용

# !pip install python-docx
# Out:
# ...
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/244.3 kB 2.0 MB/s eta 0:00:01
#    -------------------------- ------------- 163.8/244.3 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 244.3/244.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.8 MB 1.7 MB/s eta 0:00:03
#    -- ------------------------------------- 0.2/3.8 MB 2.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/3.8 MB 1.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.3/3.8 MB 1.6 MB/s eta 0:00:03
#    --- ------------------------------------ 0.4/3.8 MB 1.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.5/3.8 MB 1.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.5/3.8 MB 1.5 MB/s eta 0:00:03
# ...

# %%
# tax 읽기

from docx import Document

documemt=Document("tax.docx")

documemt
